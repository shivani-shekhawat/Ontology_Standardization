# %% [markdown]
# # Ontology Standardization Pipeline – ICD-10 Matching
# This notebook demonstrates how to standardize diagnosis codes using direct and fuzzy matching.

# %%
# !pip install fuzzywuzzy[speedup]
# Out:
# Collecting fuzzywuzzy[speedup]
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting python-levenshtein>=0.12 (from fuzzywuzzy[speedup])
#   Downloading python_levenshtein-0.27.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.27.1 (from python-levenshtein>=0.12->fuzzywuzzy[speedup])
#   Downloading levenshtein-0.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.27.1->python-levenshtein>=0.12->fuzzywuzzy[speedup])
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading python_levenshtein-0.27.1-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 3.5 MB/s eta 0:00:00
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 36.7 MB/s eta 0:00:00
# Installing collected packages: fuzzywuzzy, rapidfuzz, Levenshtein, python-levenshtein
# Successfully installed Levenshtein-0.27.1 fuzzywuzzy-0.18.0 python-levenshtein-0.27.1 rapidfuzz-3.13.0

# %%
import pandas as pd
from fuzzywuzzy import process

# %%
# Load raw EMR data
raw_data = pd.DataFrame({
    'Patient_ID': [101, 102, 103, 104],
    'Diagnosis': [' i10', 'E11.9', 'type ii diabetes', 'high bp']
})

# %%
# Load ICD-10 reference data
icd10_lookup = pd.DataFrame({
    'ICD10_Code': ['I10', 'E11.9'],
    'Description': ['Essential (primary) hypertension', 'Type 2 diabetes without complications']
})

# %%
# Step 1: Clean raw diagnosis data
raw_data['Diagnosis_Clean'] = raw_data['Diagnosis'].str.strip().str.upper()

# %%
# Step 2: Direct match with ICD-10 codes
merged_df = raw_data.merge(icd10_lookup, how='left', left_on='Diagnosis_Clean', right_on='ICD10_Code')
merged_df['Mapping_Status'] = merged_df['Description'].notnull()
merged_df
# Out:
#    Patient_ID         Diagnosis   Diagnosis_Clean ICD10_Code  \
# 0         101               i10               I10        I10
# 1         102             E11.9             E11.9      E11.9
# 2         103  type ii diabetes  TYPE II DIABETES        NaN
# 3         104           high bp           HIGH BP        NaN
#
#                              Description  Mapping_Status
# 0       Essential (primary) hypertension            True
# 1  Type 2 diabetes without complications            True
# 2                                    NaN           False
# 3                                    NaN           False
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# merged_df['Patient_ID'].plot(kind='hist', bins=20, title='Patient_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# merged_df.groupby('Diagnosis').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# merged_df.groupby('Diagnosis_Clean').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# merged_df.groupby('ICD10_Code').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# merged_df.groupby('Description').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Patient_ID']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Patient_ID'}, axis=1)
#               .sort_values('Patient_ID', ascending=True))
#   xs = counted['Patient_ID']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = merged_df.sort_values('Patient_ID', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Diagnosis')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Diagnosis', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Patient_ID')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Patient_ID']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Patient_ID'}, axis=1)
#               .sort_values('Patient_ID', ascending=True))
#   xs = counted['Patient_ID']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = merged_df.sort_values('Patient_ID', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Diagnosis_Clean')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Diagnosis_Clean', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Patient_ID')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Patient_ID']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Patient_ID'}, axis=1)
#               .sort_values('Patient_ID', ascending=True))
#   xs = counted['Patient_ID']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = merged_df.sort_values('Patient_ID', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('ICD10_Code')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='ICD10_Code', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Patient_ID')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Patient_ID']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Patient_ID'}, axis=1)
#               .sort_values('Patient_ID', ascending=True))
#   xs = counted['Patient_ID']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = merged_df.sort_values('Patient_ID', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Description')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Description', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Patient_ID')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# merged_df['Patient_ID'].plot(kind='line', figsize=(8, 4), title='Patient_ID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Diagnosis_Clean'].value_counts()
#     for x_label, grp in merged_df.groupby('Diagnosis')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Diagnosis')
# _ = plt.ylabel('Diagnosis_Clean')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['ICD10_Code'].value_counts()
#     for x_label, grp in merged_df.groupby('Diagnosis_Clean')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Diagnosis_Clean')
# _ = plt.ylabel('ICD10_Code')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Description'].value_counts()
#     for x_label, grp in merged_df.groupby('ICD10_Code')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('ICD10_Code')
# _ = plt.ylabel('Description')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Mapping_Status'].value_counts()
#     for x_label, grp in merged_df.groupby('Description')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Description')
# _ = plt.ylabel('Mapping_Status')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(merged_df['Diagnosis'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(merged_df, x='Patient_ID', y='Diagnosis', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(merged_df['Diagnosis_Clean'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(merged_df, x='Patient_ID', y='Diagnosis_Clean', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(merged_df['ICD10_Code'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(merged_df, x='Patient_ID', y='ICD10_Code', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(merged_df['Description'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(merged_df, x='Patient_ID', y='Description', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# Step 3: Fuzzy matching for unmapped cases
unmapped_rows = merged_df[merged_df['Mapping_Status'] == False].copy()

def fuzzy_match_with_score(diagnosis, descriptions):
    result = process.extractOne(diagnosis, descriptions)
    if result:
        match, score, _ = result
        return pd.Series([match, score])
    return pd.Series([None, 0])

unmapped_rows[['Fuzzy_Match', 'Match_Score']] = unmapped_rows['Diagnosis_Clean'].apply(
    lambda x: fuzzy_match_with_score(x, icd10_lookup['Description'])
)

# %%
# Step 4: Define action based on confidence threshold
threshold = 80
unmapped_rows['Action'] = unmapped_rows['Match_Score'].apply(
    lambda score: 'Auto-Map' if score >= threshold else 'Needs Manual Review'
)
unmapped_rows
# Out:
#    Patient_ID         Diagnosis   Diagnosis_Clean ICD10_Code Description  \
# 2         103  type ii diabetes  TYPE II DIABETES        NaN         NaN
# 3         104           high bp           HIGH BP        NaN         NaN
#
#    Mapping_Status                            Fuzzy_Match  Match_Score  \
# 2           False  Type 2 diabetes without complications           86
# 3           False  Type 2 diabetes without complications           49
#
#                 Action
# 2             Auto-Map
# 3  Needs Manual Review

# %%
# Final merged output
final_output = pd.concat([merged_df[merged_df['Mapping_Status']], unmapped_rows], ignore_index=True)
final_output[['Patient_ID', 'Diagnosis', 'Diagnosis_Clean', 'Fuzzy_Match', 'Match_Score', 'Action']]
# Out:
#    Patient_ID         Diagnosis   Diagnosis_Clean  \
# 0         101               i10               I10
# 1         102             E11.9             E11.9
# 2         103  type ii diabetes  TYPE II DIABETES
# 3         104           high bp           HIGH BP
#
#                              Fuzzy_Match  Match_Score               Action
# 0                                    NaN          NaN                  NaN
# 1                                    NaN          NaN                  NaN
# 2  Type 2 diabetes without complications         86.0             Auto-Map
# 3  Type 2 diabetes without complications         49.0  Needs Manual Review
